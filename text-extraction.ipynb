# %% [markdown]
# Library prep

# %%
# !pip install Bio

# %%
from Bio import Entrez 
#Entrez.email = "g.russo91@campus.unimib.it"
Entrez.email = "sezc.gianmarco.russo@gmail.com"

# %%
handle = Entrez.esearch(db="pubmed", term="\"sugar\" gut microbiota", retmax=1000000)
record = Entrez.read(handle)
print(record['Count'])
# Out:
# 859

# %%
record
# Out:
# {'Count': '859', 'RetMax': '859', 'RetStart': '0', 'IdList': ['37187520', '37182617', '37174446', '37169244', '37131223', '37125043', '37123618', '37119606', '37111220', '37110431', '37110291', '37110171', '37106841', '37101636', '37094914', '37087282', '37083181', '37083054', '37080461', '37076579', '37064908', '37062780', '37038712', '37019935', '37006470', '36996950', '36990371', '36989328', '36986107', '36986043', '36975950', '36904237', '36891383', '36879297', '36869551', '36864192', '36846996', '36843560', '36841518', '36832808', '36816591', '36815996', '36815035', '36810869', '36803220', '36786619', '36771430', '36771409', '36768946', '36748471', '36742009', '36713186', '36712404', '36709420', '36704787', '36686652', '36680556', '36655109', '36646715', '36632761', '36596207', '36577637', '36572070', '36570801', '36553810', '36542783', '36532452', '36531462', '36529358', '36524841', '36516223', '36497987', '36494898', '36478577', '36470131', '36461244', '36453489', '36432487', 
# ...

# %%
import pandas as pd
sugar_df = pd.DataFrame.from_dict({'id':record['IdList']})

# %%
sugar_df
# Out:
#            id
# 0    37187520
# 1    37182617
# 2    37174446
# 3    37169244
# 4    37131223
# ..        ...
# 854  17210919
# 855  17046302
# 856  16671057
# 857  16277764
# 858  10867049
#
# [859 rows x 1 columns]

# %%
handle = Entrez.efetch(db="pubmed", id="37187520", retmode='xml')
record = Entrez.read(handle)
handle.close()
print(record)
# Out:
# {'PubmedBookArticle': [], 'PubmedArticle': [{'MedlineCitation': DictElement({'KeywordList': [ListElement([StringElement('Cholangiocarcinoma', attributes={'MajorTopicYN': 'N'}), StringElement('Metabolomics', attributes={'MajorTopicYN': 'N'}), StringElement('Nuclear magnetic resonance spectroscopy', attributes={'MajorTopicYN': 'N'}), StringElement('Periductal fibrosis', attributes={'MajorTopicYN': 'N'})], attributes={'Owner': 'NOTNLM'})], 'OtherAbstract': [], 'OtherID': [], 'GeneralNote': [], 'CitationSubset': ['IM'], 'SpaceFlightMission': [], 'PMID': StringElement('37187520', attributes={'Version': '1'}), 'DateCompleted': {'Year': '2023', 'Month': '05', 'Day': '17'}, 'DateRevised': {'Year': '2023', 'Month': '05', 'Day': '17'}, 'Article': DictElement({'Language': ['eng'], 'ArticleDate': [DictElement({'Year': '2023', 'Month': '05', 'Day': '09'}, attributes={'DateType': 'Electronic'})], 'ELocationID': [StringElement('e15386', attributes={'EIdType': 'pii', 'ValidYN': 'Y'}), StringElement(
# ...

# %%
print(record['PubmedArticle'][0]['MedlineCitation']['Article']['Abstract']['AbstractText'][0])
# Out:
# The liver fluke <i>Opisthorchis viverrini</i> (OV), which subsequently inhabits the biliary system and results in periductal fibrosis (PDF), is one of the primarily causes of cholangiocarcinoma (CCA), a bile duct cancer with an exceptionally high incidence in the northeast of Thailand and other Greater Mekong Subregion (GMS) countries. Insights in fecal metabolic changes associated with PDF and CCA are required for further molecular research related to gut health and potential diagnostic biological marker development.

# %%
print(record['PubmedArticle'][0]['MedlineCitation']['Article']['ArticleTitle'])
# Out:
# <sup>1</sup>H NMR fecal metabolic phenotyping of periductal fibrosis- and cholangiocarcinoma-specific metabotypes defining perturbation in gut microbial-host co-metabolism.

# %%
print(record['PubmedArticle'][0]['MedlineCitation']['Article']['Journal']['JournalIssue']['PubDate']['Year'])
# Out:
# 2015

# %%
print(record['PubmedArticle'][0]['MedlineCitation']['Article']['AuthorList'][0]['AffiliationInfo'][0]['Affiliation'].split(',')[-1])
# Out:
#  Spain.

# %%
def get_title(record):
  return record['PubmedArticle'][0]['MedlineCitation']['Article']['ArticleTitle']

def get_abstract(record):
  return record['PubmedArticle'][0]['MedlineCitation']['Article']['Abstract']['AbstractText'][0]

def get_year(record):
  return record['PubmedArticle'][0]['MedlineCitation']['Article']['Journal']['JournalIssue']['PubDate']['Year']

def get_country(record):
  return record['PubmedArticle'][0]['MedlineCitation']['Article']['AuthorList'][0]['AffiliationInfo'][0]['Affiliation'].split(',')[-1]

# %%
def get_info(id):
  print(id)
  handle = Entrez.efetch(db="pubmed", id=str(id), retmode='xml')
  record = Entrez.read(handle)
  try:
    title = get_title(record)
  except:
    title = None
  try:
    abstract = get_abstract(record)
  except:
    abstract = None
  try: 
    year = get_year(record)
  except:
    year = None
  try:
    country = get_country(record)
  except:
    country = None
  return title, abstract, year, country

# %%
import time
title_list=[]
abstract_list=[]
year_list=[]
country_list=[]
for id in range(len(sugar_df['id'])):
  title, abstract, year, country = get_info(sugar_df['id'][id])
  time.sleep(1)
  title_list.append(title)
  abstract_list.append(abstract)
  year_list.append(year)
  country_list.append(country)
# Out:
# 37187520
# 37182617
# 37174446
# 37169244
# 37131223
# 37125043
# 37123618
# 37119606
# 37111220
# 37110431
# 37110291
# 37110171
# 37106841
# 37101636
# 37094914
# 37087282
# 37083181
# 37083054
# 37080461
# 37076579
# 37064908
# 37062780
# 37038712
# 37019935
# 37006470
# 36996950
# 36990371
# 36989328
# 36986107
# 36986043
# 36975950
# 36904237
# 36891383
# 36879297
# 36869551
# 36864192
# 36846996
# 36843560
# 36841518
# 36832808
# 36816591
# 36815996
# 36815035
# 36810869
# 36803220
# 36786619
# 36771430
# 36771409
# 36768946
# 36748471
# 36742009
# 36713186
# 36712404
# 36709420
# 36704787
# 36686652
# 36680556
# 36655109
# 36646715
# 36632761
# 36596207
# 36577637
# 36572070
# 36570801
# 36553810
# 36542783
# 36532452
# 36531462
# 36529358
# 36524841
# 36516223
# 36497987
# 36494898
# 36478577
# 36470131
# 36461244
# 36453489
# 36432487
# 36423772
# 36419187
# 36402426
# 36401392
# 36394327
# 36364710
# 36363813
# 36360018
# 36359816
# 36353458
# 36351282
# 36343203
# ...

# %%
sugar_df['title'] = title_list
sugar_df['abstract'] = abstract_list
sugar_df['year'] = year_list
sugar_df['country'] = country_list

# %%
sugar_df.to_csv('sugar.csv',index=False)

# %%
# %pip install nltk
# Out:
# ...
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# ...
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# ...
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# ...
#   Using cached regex-2023.5.5-cp311-cp311-win_amd64.whl (267 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script nltk.exe is installed in 'c:\Users\gchir\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pandas as pd
import nltk
from nltk.tokenize import sent_tokenize
nltk.download('punkt')
import numpy as np
import string
import re
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import WordPunctTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gchir\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gchir\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\gchir\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\gchir\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
sugar_df = pd.read_csv('sugar.csv')

# %%
def check_text(df):
  return df.title.isna() or len(df.title)<10 or df["abstract"].isna() or len(df["abstract"])<10

# %%
list_con = []
for i in range(sugar_df.shape[0]):
  tit = sugar_df.iloc[i].title
  abs = sugar_df.iloc[i].abstract

  if type(tit)==float or len(tit)< 10 or type(abs)==float or len(abs) < 10:
    list_con.append(False)
  else:
    list_con.append(True)

# %%
sugar_clean = sugar_df.iloc[list_con]

# %%
sugar_clean["all_text"] = sugar_clean["title"] +" "+ sugar_clean["abstract"]
# Out:
# C:\Users\gchir\AppData\Local\Temp\ipykernel_9620\767744626.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sugar_clean["all_text"] = sugar_clean["title"] +" "+ sugar_clean["abstract"]

# %%
def remove_punctuation(text):
    # String punctuation: !"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~
    punctuationfree = "".join([i for i in text if i not in string.punctuation])
    return punctuationfree

def character_repetition(text):
    # Pattern matching for all case alphabets
    # \1   It refers to the first capturing group.
    # {1,} It means we are matching for repetition that occurs more than one time.
    # r’\1\1' → It limits all the repetition to two characters.
    Pattern_alpha = re.compile(r"([A-Za-z])\1{1,}", re.DOTALL)
    
    Formatted_text = Pattern_alpha.sub(r"\1\1", text) 
    return Formatted_text

def remove_spaces(text):
    return text.replace('\\n', ' ').replace('\n', ' ').replace('\t',' ').replace('  ', ' ').replace('\n\n',' ')


def remove_stopwords(tokenized_text):
  stop_words = stopwords.words('english')
  tokenized_text_without_stopwords = []
  for token in tokenized_text:
    if token.lower() not in stop_words and len(token)>2:
      tokenized_text_without_stopwords.append(token)
  return tokenized_text_without_stopwords
  
def lemmatization(tokenized_text):
  wnl = WordNetLemmatizer()
  n_words = len(tokenized_text)
  for idx in range(n_words):
    tokenized_text[idx] = wnl.lemmatize(tokenized_text[idx])
  return tokenized_text


def stemming(tokenized_text):
    stemmer = SnowballStemmer("english")
    n_words = len(tokenized_text)
    for idx in range(n_words):
      tokenized_text[idx] = stemmer.stem(tokenized_text[idx])
    return tokenized_text

def preprocess(text,stopword = True, lemma = False,stem=False):
  tokenized_text =  WordPunctTokenizer().tokenize(text)
  if stopword:
    tokenized_text = remove_stopwords(tokenized_text)
  
  if lemma:
    tokenized_text = lemmatization(tokenized_text)
  
  if stem:
    tokenized_text = stemming(tokenized_text)

  return tokenized_text

# %%
sugar_clean["clean_text"] = sugar_clean["all_text"].apply(lambda x: remove_punctuation(x))
sugar_clean["clean_text"] = sugar_clean["clean_text"].apply(lambda x: x.lower())
sugar_clean["clean_text"] = sugar_clean["clean_text"].apply(lambda x: re.sub(r'\d+', '', x))
sugar_clean["clean_text"] = sugar_clean["clean_text"].apply(lambda x: character_repetition(x))
sugar_clean["clean_text"] = sugar_clean["clean_text"].apply(lambda x: remove_spaces(x))
# Out:
# C:\Users\gchir\AppData\Local\Temp\ipykernel_9620\715679533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sugar_clean["clean_text"] = sugar_clean["all_text"].apply(lambda x: remove_punctuation(x))
# C:\Users\gchir\AppData\Local\Temp\ipykernel_9620\715679533.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sugar_clean["clean_text"] = sugar_clean["clean_text"].apply(lambda x: x.lower())
# C:\Users\gchir\AppData\Local\Temp\ipykernel_9620\715679533.py:3: SettingWithCopyWarning:
# ...

# %%
sugar_clean["clean_title"] = sugar_clean["title"].apply(lambda x: remove_punctuation(x))
sugar_clean["clean_title"] = sugar_clean["clean_title"].apply(lambda x: x.lower())
sugar_clean["clean_title"] = sugar_clean["clean_title"].apply(lambda x: re.sub(r'\d+', '', x))
sugar_clean["clean_title"] = sugar_clean["clean_title"].apply(lambda x: character_repetition(x))
sugar_clean["clean_title"] = sugar_clean["clean_title"].apply(lambda x: remove_spaces(x))
# Out:
# C:\Users\gchir\AppData\Local\Temp\ipykernel_9620\1643901965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sugar_clean["clean_title"] = sugar_clean["title"].apply(lambda x: remove_punctuation(x))
# C:\Users\gchir\AppData\Local\Temp\ipykernel_9620\1643901965.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sugar_clean["clean_title"] = sugar_clean["clean_title"].apply(lambda x: x.lower())
# C:\Users\gchir\AppData\Local\Temp\ipykernel_9620\1643901965.py:3: SettingWithCopyWarning:
# ...

# %%
sugar_clean["clean_abstract"] = sugar_clean["abstract"].apply(lambda x: remove_punctuation(x))
sugar_clean["clean_abstract"] = sugar_clean["clean_abstract"].apply(lambda x: x.lower())
sugar_clean["clean_abstract"] = sugar_clean["clean_abstract"].apply(lambda x: re.sub(r'\d+', '', x))
sugar_clean["clean_abstract"] = sugar_clean["clean_abstract"].apply(lambda x: character_repetition(x))
sugar_clean["clean_abstract"] = sugar_clean["clean_abstract"].apply(lambda x: remove_spaces(x))
# Out:
# C:\Users\gchir\AppData\Local\Temp\ipykernel_9620\1192916993.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sugar_clean["clean_abstract"] = sugar_clean["abstract"].apply(lambda x: remove_punctuation(x))
# C:\Users\gchir\AppData\Local\Temp\ipykernel_9620\1192916993.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sugar_clean["clean_abstract"] = sugar_clean["clean_abstract"].apply(lambda x: x.lower())
# ...

# %%
import torch
import pandas as pd
from transformers import BertTokenizer, BertModel

def get_emb(food_label,tokenizer,model):

  tokenized_text = tokenizer.tokenize(food_label)
  indexed_tokens = tokenizer.convert_tokens_to_ids(tokenized_text)
  segments_ids = [1] * len(tokenized_text)
  tokens_tensor = torch.tensor([indexed_tokens])[:,:512]
  segments_tensors = torch.tensor([segments_ids])[:,:512]
  
  with torch.no_grad():

    outputs = model(tokens_tensor, segments_tensors)
    hidden_states = outputs[2]
  
  return hidden_states[-1].mean(dim=1)

def get_bert_embeddings(label_path, model_name = "bert-large-uncased",column = "Category"):
    if type(label_path) == "str":
      labels = pd.read_csv(label_path,encoding="latin1",sep=";")
    else:
      labels = label_path
    tokenizer = BertTokenizer.from_pretrained(model_name)
    bert_model = BertModel.from_pretrained(model_name,
                                  output_hidden_states = True)
    
    bert_model.eval()


    for i in range(labels.shape[0]):
      if i == 0:
        bert_emb = get_emb(labels[column][i],tokenizer,bert_model)

      else:
        bert_emb = torch.cat([bert_emb,get_emb(labels[column][i],tokenizer,bert_model)], dim = 0)

    return bert_emb

# %%
sugar_clean
# Out:
#            id                                              title
# 0    37187520  <sup>1</sup>H NMR fecal metabolic phenotyping ...  \
# 1    37182617  Integrated microbiota and metabolite profiling...
# 2    37174446  Catabolism of <i>Dictyophora indusiata</i> Pol...
# 3    37169244  Intake of Caffeine Containing Sugar Diet Remod...
# 4    37131223  Maternal Western diet mediates susceptibility ...
# ..        ...                                                ...
# 851  17210919  Mechanisms underlying the resistance to diet-i...
# 852  17046302  Contrasting digestive strategies in four New Z...
# 853  16671057  Metabolism of Maillard reaction products by th...
# 854  16277764  Human gut microbiota does not ferment erythritol.
# 855  10867049  In vitro fermentation pattern of D-tagatose is...
#
#                                               abstract  year
# 0    The liver fluke <i>Opisthorchis viverrini</i> ...  2023  \
# ...

# %%
sugar_clean = sugar_clean.reset_index(drop=True)

# %%
sugar_clean.to_csv("sugar_clean.csv",index=False)

# %%
sugar_clean = pd.read_csv("sugar_clean.csv")

# %%
sugar_clean
# Out:
#            id                                              title
# 0    37187520  <sup>1</sup>H NMR fecal metabolic phenotyping ...  \
# 1    37182617  Integrated microbiota and metabolite profiling...
# 2    37174446  Catabolism of <i>Dictyophora indusiata</i> Pol...
# 3    37169244  Intake of Caffeine Containing Sugar Diet Remod...
# 4    37131223  Maternal Western diet mediates susceptibility ...
# ..        ...                                                ...
# 851  17210919  Mechanisms underlying the resistance to diet-i...
# 852  17046302  Contrasting digestive strategies in four New Z...
# 853  16671057  Metabolism of Maillard reaction products by th...
# 854  16277764  Human gut microbiota does not ferment erythritol.
# 855  10867049  In vitro fermentation pattern of D-tagatose is...
#
#                                               abstract  year
# 0    The liver fluke <i>Opisthorchis viverrini</i> ...  2023  \
# ...

# %%
title_emb = get_bert_embeddings(sugar_clean,column ="clean_title")
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
title_emb.shape
# Out:
# torch.Size([856, 1024])

# %%
abstract_emb = get_bert_embeddings(sugar_clean,column = "clean_abstract")
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
title_emb_df = pd.DataFrame(title_emb.numpy())
abstract_emb_df = pd.DataFrame(abstract_emb.numpy())

# %%
title_emb_df
# Out:
#          0         1         2         3         4         5         6
# 0   -0.214320  0.009796 -0.046036  0.084108 -0.649906  0.005261 -0.031523  \
# 1   -0.416309 -0.273359 -0.035703  0.000207 -0.188805  0.078119 -0.155178
# 2   -0.327976 -0.164913  0.000046  0.391815 -0.350749  0.026766 -0.205336
# 3   -0.212601 -0.465339  0.175830  0.186043 -0.118717  0.061685  0.337832
# 4   -0.459910 -0.251220 -0.044440 -0.160723 -0.168631 -0.016928  0.304167
# ..        ...       ...       ...       ...       ...       ...       ...
# 851 -1.337879  0.045892 -0.568156  0.010016 -0.045315 -0.414031  1.071262
# 852 -0.162505 -0.269573 -0.034574 -0.168443 -0.464637  0.211850  0.122122
# 853 -1.026804 -0.320569  0.648018  0.472081 -0.425289  0.331412  0.785510
# 854 -0.312360 -0.243113 -0.046935 -0.428416 -0.505645 -0.135107 -0.143893
# 855 -0.343141 -0.194817 -0.081037 -0.484588 -0.189934  0.246951  0.010062
#
#          7         8         9     ...      1014      1015      1016
# ...

# %%
title_emb_df.to_csv("title_emb.csv")
abstract_emb_df.to_csv("abstract_emb.csv")

# %%
# Remove from sentence collection not valid monograms or bigrams
def validate_token(token, stopwords):

  if len(token) > 2 and token not in stopwords:
    if len(token.split()) < 2:
      return True
    else:
      if token.split()[0] in stopwords and token.split()[1] in stopwords:
        return False
      else:
        if (token.split()[0] in stopwords and len(token.split()[0])) < 3 or (token.split()[1] in stopwords and len(token.split()[1])):
          return False
        else:
          return True

  return False

# %%
# %pip install scipy
# Out:
# ...
#
#   Using cached scipy-1.10.1-cp311-cp311-win_amd64.whl (42.2 MB)
# ...

# %%
# %pip install sklearn
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
# ...

# %%
from scipy.cluster.hierarchy import dendrogram
from sklearn.preprocessing import Normalizer
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import AgglomerativeClustering
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 from scipy.cluster.hierarchy import dendrogram
#       2 from sklearn.preprocessing import Normalizer
#       3 from sklearn.decomposition import PCA
#
# ModuleNotFoundError: No module named 'scipy'

# %%
title_emb.to_numpy()

# %%
# Plot dendrogram
def plot_dendrogram(model, **kwargs):
  
    # Create linkage matrix and then plot the dendrogram
    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)

    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack([model.children_, model.distances_, counts]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
# Perform Hierarchical Clustering on sentence embeddings
clustering = AgglomerativeClustering(n_clusters=None, memory="./tree", compute_full_tree=True, distance_threshold=.2)
_ = clustering.fit(text_embeddings)

# %%
twelve_clusters = {
    0: "Digitalizzazione Amministrazione Pubblica",
    1: "Formazione professionale",
    2: "Sicurezza",
    3: "Infrastrutture digitali",
    4: "Pari opportunità",
    5: "Farnesina e Affari Esteri",
    6: "Potenziamento SSN",
    7: "Territorio e Ambiente",
    8: "Adeguamento informatico Pubblica Amministrazione",
    9: "Riqualificazione infrastrutture",
    10: "Accessibilità Digitale",
    11: "Adeguamento informatico didattica"
}

six_clusters = {
    0: "Emergenza sanitaria",
    1: "Pubblica Amministrazione",
    2: "Infrastrutture",
    3: "Territorio e Ambiente",
    4: "Pari opportunità",
    5: "Formazione"
}

two_clusters = {
    0: "Sfera pubblica",
    1: "Sfera privata"
}

# %%
import matplotlib.pyplot as plt
# Visualize hierarchy dendrogram with cluster cardinality
plot_dendrogram(clustering, truncate_mode='level', p=3)
plt.title("Recovery Fund, hierarchy of clusters")
plt.xlabel("Cluster cardinality")
plt.show()

# %%
# Make a copy of Recovery Fund data for visualization
hierarchy_data = sugar_clean.copy()

# Find last twelve clusters hierarchy levels in order to make the visualization
for c in range(2, 13):

  clustering_post = AgglomerativeClustering(n_clusters=c)
  post_labels = clustering_post.fit_predict(text_embeddings)

  if c < 12:
    hierarchy_data[f"Labels_{c}"] = [f"cluster_{c}_{label}" for label in post_labels]
  else:
    hierarchy_data[f"Labels_{c}"] = post_labels

# Store hierarchy as csv
hierarchy_data["Labels_12"] = hierarchy_data["Labels_12"].map(twelve_clusters)
hierarchy_data[hierarchy_data.columns[-11:]].to_csv("datasets/cluster_hierarchy.csv")

# %%
import nltk
import treetaggerwrapper
from nltk import bigrams, FreqDist
from nltk.tokenize import RegexpTokenizer

from sklearn.preprocessing import Normalizer
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import AgglomerativeClustering

import torch
from transformers import BertTokenizer, BertConfig, BertModel

import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from scipy.cluster.hierarchy import dendrogram

# %%
stopwords = nltk.corpus.stopwords.words("italian")
frequencies = nltk.FreqDist(tokens)
common_words = [word for word, freq in frequencies.most_common(200)]
lemmatized_stopwords = [lemmatizer(word) for word in stopwords]
enriched_stopwords = set(stopwords + lemmatized_stopwords + common_words + ["@card@"])

# %%
# Make a copy of Recovery Fund data for enrichment
cluster_data = sugar_clean.copy()
plot_grids = [(1, 2), (2, 3), (3, 4)]
cluster_names = [two_clusters, six_clusters, twelve_clusters]

# Extract only second, sixth and twelfth hierarchy level
for c, grid, titles in zip([2, 6, 12], plot_grids, cluster_names):

  # Extract cluster and store labels
  clustering = AgglomerativeClustering(n_clusters=c)
  labels = clustering.fit_predict(text_embeddings)
  cluster_data[f"Labels_{c}"] = labels

  # Generate plotgrid
  fig, ax = plt.subplots(*grid, figsize=(15,10))
  rows, cols = grid

  # Extract word clouds from clusters
  for index, label in enumerate(np.unique(cluster_data[f"Labels_{c}"])):

    # Get total text to be analyzed
    text = " ".join(cluster_data[cluster_data[f"Labels_{c}"] == label]["Obiettivo / Motivazione"].map(lemmatizer))

    # Extract monogram end bigram frequencies from text as dictionary
    tokenizer = RegexpTokenizer(r'\w+')
    sent_words = tokenizer.tokenize(text)
    freq_monogram = FreqDist(sent_words)
    freq_bigram = FreqDist(bigrams(sent_words))
    dict_monogram = dict(freq_monogram)
    dict_bigram = {" ".join(k):v for k, v in dict(freq_bigram).items()}
    dict_token = {**dict_monogram, **dict_bigram}

    # Get only valid words and remove stopwords, storing the frequencies for analysis
    clean_dict = {k:v for k, v in dict_token.items() if validate_token(k, enriched_stopwords)}
    freq_df = pd.DataFrame([(k, v) for k, v in clean_dict.items()], columns=["ngram", "freq"]).nlargest(100, ['freq'])
    freq_df.to_csv(f"frequencies/frequencies_{c}_{label}.csv")

    # Generat and plot the word cloud
    wordcloud = WordCloud(stopwords=enriched_stopwords, background_color="white").generate_from_frequencies(clean_dict)

    if c == 2:
      ax[index%c].imshow(wordcloud, interpolation='bilinear')
      ax[index%c].axis("off")
    else:
      ax[index//cols][index%cols].imshow(wordcloud, interpolation='bilinear')
      ax[index//cols][index%cols].axis("off")

  fig.suptitle(f"Hierarchical clustering word clouds: granularità {c} clusters")
  plt.show()

# Set cluster names for visualizations
cluster_data["Labels_2"] = cluster_data["Labels_2"].map(two_clusters)
cluster_data["Labels_6"] = cluster_data["Labels_6"].map(six_clusters)
cluster_data["Labels_12"] = cluster_data["Labels_12"].map(twelve_clusters)

# Export dataset
cluster_data[["Costo", "Labels_2", "Labels_6", "Labels_12"]].to_csv("datasets/clustering_output.csv")
